# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
import random
from IPython.display import display
import re

# 1) Create a Session with a random or fixed User-Agent
s = requests.Session()
s.headers.update({
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/109.0.0.0 Safari/537.36"
    )
})

def get_soup(session, url):
    """Fetch a URL, return BeautifulSoup or None on failure."""
    try:
        resp = session.get(url, timeout=10)
        # Check status code
        if resp.status_code == 200:
            return BeautifulSoup(resp.text, 'html.parser')
        elif resp.status_code == 429:
            print("Received 429. Too many requests. Backing off.")
            # Wait longer or do an exponential backoff
            time.sleep(60)
            return None
        else:
            print(f"Error: got status {resp.status_code} for {url}")
            return None
    except requests.RequestException as e:
        print(f"Request failed: {e}")
        return None

def get_team_links(soup):
    """Extract team links from the league table soup."""
    tables = soup.select('table.stats_table')
    if not tables:
        print("No stats_table found!")
        return []
    league_table = tables[0]
    links = league_table.find_all('a')
    hrefs = [l.get('href') for l in links if l.get('href')]
    hrefs = [h for h in hrefs if 'squads' in h]
    team_urls = [f"https://fbref.com{h}" for h in hrefs]
    return team_urls

def get_player_links(session, team_url):
    soup = get_soup(session, team_url)
    if not soup:
        return []
    tables = soup.select('table')
    if not tables:
        return []
    player_table = tables[0]
    links = player_table.find_all('a')
    hrefs = [l.get('href') for l in links if l.get('href')]
    hrefs = [h for h in hrefs if 'players' in h and 'matchlogs' not in h]
    return [f"https://fbref.com{h}" for h in hrefs]

def get_player_data(session, player_url):
    # Fetch and parse the page
    soup = get_soup(session, player_url)
    if not soup:
        print(f"Failed to retrieve page for {player_url}")
        return None

    # Extract player name
    player_name = None
    h1_tag = soup.find("h1", {"itemprop": "name"}) or soup.find("h1")
    player_name = h1_tag.get_text(strip=True) if h1_tag else "Unknown"

    try:
        # Extract player stats table
        tables = pd.read_html(str(soup), match=player_name)
        if not tables:
            print(f"No matching table found for {player_name}.")
            return None

        df = tables[0]  # Assume first table is relevant

        # Extract minutes played
        minutes = None
        footer_div = soup.find("div", id=re.compile("^tfooter_scout_summary_"))
        if footer_div:
            strong_tag = footer_div.find("strong")
            if strong_tag:
                minutes_text = strong_tag.get_text(strip=True)
                minutes = int(minutes_text.split()[0])  # Extract numeric value safely

        # Add "Minutes Played" as a new row if minutes were found
        if minutes is not None:
            print(f"Found {minutes} minutes for {player_name}")
            new_row = pd.DataFrame({"Stat": ["Minutes Played"], "Value": [minutes]})
            df = pd.concat([df, new_row], ignore_index=True)

        return df

    except ValueError as e:
        print(f"Error processing {player_name}: {e}")
        return None
    
def convert_csv(df):
    return df.to_csv(index=False)

def main():
    team_data = {}
    league_table_url = "https://fbref.com/en/comps/9/Premier-League-Stats"
    
    soup_league = get_soup(s, league_table_url)
    if not soup_league:
        return
    
    team_urls = get_team_links(soup_league)
    
    # Example: just scrape first few teams to limit requests
    # Create one list per team to store player data
    
    for team_url in team_urls[:1]:
        team_name = team_url.split("/")[-1].replace("-", " ")
        print(f"Scraping {team_name}")
        team_data[team_name] = {'players': [], 'keepers': []}   
        player_urls = get_player_links(s, team_url)
        for purl in player_urls:
            print(f"Scraping {purl}")
            df = get_player_data(s, purl)
            if df is not None:
                if df.iloc[0, 0] == "PSxG-GA":
                    team_data[team_name]['keepers'].append(df)
                else:
                    team_data[team_name]['players'].append(df)
            else:
                print(f"No data for {purl}")
            # random sleep
            time.sleep(random.uniform(2, 5))
    
    print(f"Scraped data for {len(team_data)} teams.")
    print("Data keys:", team_data.keys())
    print("Data for first team:", team_data['Liverpool Stats'])



    # Convert each team's data to a single CSV for players and another for keepers
    for team, data in team_data.items():
        for key, dfs in data.items():
            if dfs:  # Ensure there is data to concatenate
                combined_df = pd.concat(dfs, ignore_index=True)  # Combine all DataFrames
                print(f"\n===== {team} - {key.upper()} =====")
                display(combined_df)
                csv = convert_csv(combined_df)  # Convert to CSV format
                filename = f"{team}_{key}.csv"
                
                with open(filename, "w") as f:
                    f.write(csv)
                    print(f"Saved {filename}")


if __name__ == "__main__":
    main()
# Out:
# Scraping Liverpool Stats
# Scraping https://fbref.com/en/players/e06683ca/Virgil-van-Dijk
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 4386 minutes for Virgil van Dijk
# Scraping https://fbref.com/en/players/e342ad68/Mohamed-Salah
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 3642 minutes for Mohamed Salah
# Scraping https://fbref.com/en/players/b8e740fb/Ryan-Gravenberch
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 3037 minutes for Ryan Gravenberch
# Scraping https://fbref.com/en/players/cd1acf9d/Trent-Alexander-Arnold
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 2851 minutes for Trent Alexander-Arnold
# Scraping https://fbref.com/en/players/2e4f5f03/Andrew-Robertson
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 3244 minutes for Andrew Robertson
# Scraping https://fbref.com/en/players/83d074ff/Alexis-Mac-Allister
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 3687 minutes for Alexis Mac Allister
# Scraping https://fbref.com/en/players/4a1a9578/Luis-Diaz
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 3384 minutes for Luis Díaz
# Scraping https://fbref.com/en/players/934e1968/Dominik-Szoboszlai
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 2587 minutes for Dominik Szoboszlai
# Scraping https://fbref.com/en/players/5ed9b537/Ibrahima-Konate
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 2584 minutes for Ibrahima Konaté
# Scraping https://fbref.com/en/players/7a2e46a8/Alisson
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 2508 minutes for Alisson
# Scraping https://fbref.com/en/players/1971591f/Cody-Gakpo
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 2797 minutes for Cody Gakpo
# Scraping https://fbref.com/en/players/4fb9c88f/Curtis-Jones
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 1782 minutes for Curtis Jones
# Scraping https://fbref.com/en/players/62d7ef38/Caoimhin-Kelleher
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 2070 minutes for Caoimhín Kelleher
# Scraping https://fbref.com/en/players/4d77b365/Darwin-Nunez
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 2148 minutes for Darwin Núñez
# Scraping https://fbref.com/en/players/178ae8f8/Diogo-Jota
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 1087 minutes for Diogo Jota
# Scraping https://fbref.com/en/players/7a11550b/Joe-Gomez
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 1536 minutes for Joe Gomez
# Scraping https://fbref.com/en/players/f315ca93/Kostas-Tsimikas
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 891 minutes for Kostas Tsimikas
# Scraping https://fbref.com/en/players/4125cb98/Jarell-Quansah
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 1493 minutes for Jarell Quansah
# Scraping https://fbref.com/en/players/bbd67769/Conor-Bradley
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 1278 minutes for Conor Bradley
# Scraping https://fbref.com/en/players/c149016b/Wataru-Endo
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 1435 minutes for Wataru Endo
# Scraping https://fbref.com/en/players/b9e1436c/Harvey-Elliott
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 1291 minutes for Harvey Elliott
# Scraping https://fbref.com/en/players/b0f7e36c/Federico-Chiesa
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Found 1176 minutes for Federico Chiesa
# Scraping https://fbref.com/en/players/12bb4d6a/Vitezslav-Jaros
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Error processing Vitezslav Jaros: No tables found matching pattern 'Vitezslav Jaros'
# No data for https://fbref.com/en/players/12bb4d6a/Vitezslav-Jaros
# Scraping https://fbref.com/en/players/003cf4d1/Jayden-Danns
# Error processing Jayden Danns: No tables found matching pattern 'Jayden Danns'
# No data for https://fbref.com/en/players/003cf4d1/Jayden-Danns
# Scraping https://fbref.com/en/players/fd08a24b/Harvey-Davies
# Error processing Harvey Davies: No tables found matching pattern 'Harvey Davies'
# No data for https://fbref.com/en/players/fd08a24b/Harvey-Davies
# Scraping https://fbref.com/en/players/bf973eeb/James-McConnell
# Error processing James McConnell: No tables found matching pattern 'James McConnell'
# No data for https://fbref.com/en/players/bf973eeb/James-McConnell
# Scraping https://fbref.com/en/players/2bc28bb9/Tyler-Morton
# Found 1141 minutes for Tyler Morton
# Scraping https://fbref.com/en/players/398a24f6/Amara-Nallo
# C:\Users\tobia\AppData\Local\Temp\ipykernel_2716\3431932931.py:78: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup), match=player_name)
# Error processing Amara Nallo: No tables found matching pattern 'Amara Nallo'
# No data for https://fbref.com/en/players/398a24f6/Amara-Nallo
# Scraping https://fbref.com/en/players/1d3b3d77/Trey-Nyoni
# Error processing Trey Nyoni: No tables found matching pattern 'Trey Nyoni'
# No data for https://fbref.com/en/players/1d3b3d77/Trey-Nyoni
# Scraped data for 1 teams.
# Data keys: dict_keys(['Liverpool Stats'])
# Data for first team: {'players': [                   Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.06        72.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.07        85.0             NaN     NaN
# 2                Shots Total   0.96        96.0             NaN     NaN
# 3                    Assists   0.02        53.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.02        52.0             NaN     NaN
# 5                 npxG + xAG   0.09        74.0             NaN     NaN
# 6      Shot-Creating Actions   1.31        89.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  81.20        93.0             NaN     NaN
# 9          Pass Completion %  92.3%        92.0             NaN     NaN
# 10        Progressive Passes   4.84        84.0             NaN     NaN
# 11       Progressive Carries   0.55        46.0             NaN     NaN
# 12       Successful Take-Ons   0.10        28.0             NaN     NaN
# 13         Touches (Att Pen)   1.62        95.0             NaN     NaN
# 14    Progressive Passes Rec   0.16        32.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   0.90         7.0             NaN     NaN
# 17             Interceptions   1.09        51.0             NaN     NaN
# 18                    Blocks   0.80         7.0             NaN     NaN
# 19                Clearances   3.69        35.0             NaN     NaN
# 20               Aerials Won   2.93        85.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  4386.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.52        93.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.58        99.0             NaN     NaN
# 2                Shots Total   4.05        99.0             NaN     NaN
# 3                    Assists   0.54        99.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.43        98.0             NaN     NaN
# 5                 npxG + xAG   1.01        99.0             NaN     NaN
# 6      Shot-Creating Actions   4.84        82.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  34.60        44.0             NaN     NaN
# 9          Pass Completion %  72.5%        25.0             NaN     NaN
# 10        Progressive Passes   4.57        70.0             NaN     NaN
# 11       Progressive Carries   3.95        60.0             NaN     NaN
# 12       Successful Take-Ons   1.33        37.0             NaN     NaN
# 13         Touches (Att Pen)   9.61        99.0             NaN     NaN
# 14    Progressive Passes Rec  13.00        96.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   0.52         4.0             NaN     NaN
# 17             Interceptions   0.12         2.0             NaN     NaN
# 18                    Blocks   0.30         1.0             NaN     NaN
# 19                Clearances   0.17         5.0             NaN     NaN
# 20               Aerials Won   0.15        11.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  3642.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.03        30.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.04        30.0             NaN     NaN
# 2                Shots Total   0.71        27.0             NaN     NaN
# 3                    Assists   0.06        39.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.11        66.0             NaN     NaN
# 5                 npxG + xAG   0.15        47.0             NaN     NaN
# 6      Shot-Creating Actions   2.31        52.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  54.20        60.0             NaN     NaN
# 9          Pass Completion %  89.6%        90.0             NaN     NaN
# 10        Progressive Passes   5.81        71.0             NaN     NaN
# 11       Progressive Carries   2.28        86.0             NaN     NaN
# 12       Successful Take-Ons   1.19        88.0             NaN     NaN
# 13         Touches (Att Pen)   1.07        46.0             NaN     NaN
# 14    Progressive Passes Rec   2.34        66.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   2.22        58.0             NaN     NaN
# 17             Interceptions   1.84        96.0             NaN     NaN
# 18                    Blocks   1.39        69.0             NaN     NaN
# 19                Clearances   1.24        39.0             NaN     NaN
# 20               Aerials Won   0.71        38.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  3037.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.06        67.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.08        81.0             NaN     NaN
# 2                Shots Total   1.83        97.0             NaN     NaN
# 3                    Assists   0.25        94.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.29        98.0             NaN     NaN
# 5                 npxG + xAG   0.36        96.0             NaN     NaN
# 6      Shot-Creating Actions   3.95        97.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  76.14        96.0             NaN     NaN
# 9          Pass Completion %  74.0%        19.0             NaN     NaN
# 10        Progressive Passes   8.27        99.0             NaN     NaN
# 11       Progressive Carries   1.93        53.0             NaN     NaN
# 12       Successful Take-Ons   0.51        35.0             NaN     NaN
# 13         Touches (Att Pen)   1.61        57.0             NaN     NaN
# 14    Progressive Passes Rec   4.04        44.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   2.30        69.0             NaN     NaN
# 17             Interceptions   1.20        79.0             NaN     NaN
# 18                    Blocks   1.26        61.0             NaN     NaN
# 19                Clearances   1.52        12.0             NaN     NaN
# 20               Aerials Won   0.09         1.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  2851.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.06        59.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.08        81.0             NaN     NaN
# 2                Shots Total   0.58        42.0             NaN     NaN
# 3                    Assists   0.08        52.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.24        96.0             NaN     NaN
# 5                 npxG + xAG   0.32        94.0             NaN     NaN
# 6      Shot-Creating Actions   4.05        98.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  82.29        99.0             NaN     NaN
# 9          Pass Completion %  83.6%        78.0             NaN     NaN
# 10        Progressive Passes   7.35        97.0             NaN     NaN
# 11       Progressive Carries   2.86        85.0             NaN     NaN
# 12       Successful Take-Ons   0.22         7.0             NaN     NaN
# 13         Touches (Att Pen)   2.55        89.0             NaN     NaN
# 14    Progressive Passes Rec   4.97        68.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   1.58        23.0             NaN     NaN
# 17             Interceptions   0.55        15.0             NaN     NaN
# 18                    Blocks   0.69         6.0             NaN     NaN
# 19                Clearances   1.94        24.0             NaN     NaN
# 20               Aerials Won   0.25         3.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  3244.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.15        82.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.14        85.0             NaN     NaN
# 2                Shots Total   1.59        83.0             NaN     NaN
# 3                    Assists   0.20        87.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.20        93.0             NaN     NaN
# 5                 npxG + xAG   0.34        91.0             NaN     NaN
# 6      Shot-Creating Actions   4.35        94.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  59.54        76.0             NaN     NaN
# 9          Pass Completion %  85.7%        60.0             NaN     NaN
# 10        Progressive Passes   6.96        86.0             NaN     NaN
# 11       Progressive Carries   1.42        61.0             NaN     NaN
# 12       Successful Take-Ons   0.56        46.0             NaN     NaN
# 13         Touches (Att Pen)   2.07        82.0             NaN     NaN
# 14    Progressive Passes Rec   2.66        71.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   3.17        91.0             NaN     NaN
# 17             Interceptions   0.90        42.0             NaN     NaN
# 18                    Blocks   2.29        99.0             NaN     NaN
# 19                Clearances   0.95        20.0             NaN     NaN
# 20               Aerials Won   0.81        48.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  3687.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.43        84.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.45        96.0             NaN     NaN
# 2                Shots Total   3.09        83.0             NaN     NaN
# 3                    Assists   0.13        27.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.21        55.0             NaN     NaN
# 5                 npxG + xAG   0.66        90.0             NaN     NaN
# 6      Shot-Creating Actions   5.35        90.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  36.22        49.0             NaN     NaN
# 9          Pass Completion %  85.5%        96.0             NaN     NaN
# 10        Progressive Passes   3.83        51.0             NaN     NaN
# 11       Progressive Carries   4.68        75.0             NaN     NaN
# 12       Successful Take-Ons   2.29        76.0             NaN     NaN
# 13         Touches (Att Pen)   7.15        94.0             NaN     NaN
# 14    Progressive Passes Rec  10.24        79.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   1.20        48.0             NaN     NaN
# 17             Interceptions   0.19         8.0             NaN     NaN
# 18                    Blocks   0.64        21.0             NaN     NaN
# 19                Clearances   0.32        24.0             NaN     NaN
# 20               Aerials Won   0.59        60.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  3384.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.21        36.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.30        75.0             NaN     NaN
# 2                Shots Total   2.71        69.0             NaN     NaN
# 3                    Assists   0.14        28.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.21        58.0             NaN     NaN
# 5                 npxG + xAG   0.50        67.0             NaN     NaN
# 6      Shot-Creating Actions   4.77        80.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  57.26        93.0             NaN     NaN
# 9          Pass Completion %  84.2%        94.0             NaN     NaN
# 10        Progressive Passes   5.74        89.0             NaN     NaN
# 11       Progressive Carries   2.99        37.0             NaN     NaN
# 12       Successful Take-Ons   0.80        12.0             NaN     NaN
# 13         Touches (Att Pen)   4.42        54.0             NaN     NaN
# 14    Progressive Passes Rec   6.09        21.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   0.94        25.0             NaN     NaN
# 17             Interceptions   0.59        81.0             NaN     NaN
# 18                    Blocks   1.43        94.0             NaN     NaN
# 19                Clearances   0.42        34.0             NaN     NaN
# 20               Aerials Won   0.77        75.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  2587.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.07        78.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.06        69.0             NaN     NaN
# 2                Shots Total   0.52        54.0             NaN     NaN
# 3                    Assists   0.07        91.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.03        63.0             NaN     NaN
# 5                 npxG + xAG   0.08        63.0             NaN     NaN
# 6      Shot-Creating Actions   1.08        75.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  70.08        82.0             NaN     NaN
# 9          Pass Completion %  88.7%        67.0             NaN     NaN
# 10        Progressive Passes   4.42        78.0             NaN     NaN
# 11       Progressive Carries   1.01        85.0             NaN     NaN
# 12       Successful Take-Ons   0.21        62.0             NaN     NaN
# 13         Touches (Att Pen)   0.66        35.0             NaN     NaN
# 14    Progressive Passes Rec   0.07        13.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   1.53        55.0             NaN     NaN
# 17             Interceptions   1.01        38.0             NaN     NaN
# 18                    Blocks   1.08        27.0             NaN     NaN
# 19                Clearances   4.08        45.0             NaN     NaN
# 20               Aerials Won   3.27        91.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  2584.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.55        96.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.44        93.0             NaN     NaN
# 2                Shots Total   3.25        86.0             NaN     NaN
# 3                    Assists   0.23        63.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.30        85.0             NaN     NaN
# 5                 npxG + xAG   0.74        94.0             NaN     NaN
# 6      Shot-Creating Actions   4.57        75.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  32.72        31.0             NaN     NaN
# 9          Pass Completion %  77.0%        56.0             NaN     NaN
# 10        Progressive Passes   3.44        36.0             NaN     NaN
# 11       Progressive Carries   2.93        34.0             NaN     NaN
# 12       Successful Take-Ons   1.77        60.0             NaN     NaN
# 13         Touches (Att Pen)   5.79        80.0             NaN     NaN
# 14    Progressive Passes Rec  11.26        88.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   1.35        60.0             NaN     NaN
# 17             Interceptions   0.51        66.0             NaN     NaN
# 18                    Blocks   1.16        79.0             NaN     NaN
# 19                Clearances   0.55        54.0             NaN     NaN
# 20               Aerials Won   1.25        89.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  2797.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.15        83.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.23        97.0             NaN     NaN
# 2                Shots Total   1.82        90.0             NaN     NaN
# 3                    Assists   0.25        94.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.17        86.0             NaN     NaN
# 5                 npxG + xAG   0.39        95.0             NaN     NaN
# 6      Shot-Creating Actions   2.78        65.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  58.79        74.0             NaN     NaN
# 9          Pass Completion %  92.6%        99.0             NaN     NaN
# 10        Progressive Passes   5.40        64.0             NaN     NaN
# 11       Progressive Carries   1.72        73.0             NaN     NaN
# 12       Successful Take-Ons   1.11        85.0             NaN     NaN
# 13         Touches (Att Pen)   3.64        96.0             NaN     NaN
# 14    Progressive Passes Rec   5.56        96.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   1.92        39.0             NaN     NaN
# 17             Interceptions   0.35         2.0             NaN     NaN
# 18                    Blocks   0.96        25.0             NaN     NaN
# 19                Clearances   0.40         2.0             NaN     NaN
# 20               Aerials Won   0.61        32.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  1782.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.50        72.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.60        92.0             NaN     NaN
# 2                Shots Total   3.77        92.0             NaN     NaN
# 3                    Assists   0.13        59.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.11        45.0             NaN     NaN
# 5                 npxG + xAG   0.71        85.0             NaN     NaN
# 6      Shot-Creating Actions   2.47        64.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  18.98        40.0             NaN     NaN
# 9          Pass Completion %  67.3%        31.0             NaN     NaN
# 10        Progressive Passes   1.97        65.0             NaN     NaN
# 11       Progressive Carries   2.43        87.0             NaN     NaN
# 12       Successful Take-Ons   0.75        62.0             NaN     NaN
# 13         Touches (Att Pen)   7.12        95.0             NaN     NaN
# 14    Progressive Passes Rec   7.79        93.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   1.38        97.0             NaN     NaN
# 17             Interceptions   0.21        60.0             NaN     NaN
# 18                    Blocks   0.50        39.0             NaN     NaN
# 19                Clearances   0.88        70.0             NaN     NaN
# 20               Aerials Won   1.47        40.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  2148.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.58        82.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.65        95.0             NaN     NaN
# 2                Shots Total   3.39        84.0             NaN     NaN
# 3                    Assists   0.25        89.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.21        90.0             NaN     NaN
# 5                 npxG + xAG   0.85        99.0             NaN     NaN
# 6      Shot-Creating Actions   3.15        86.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  26.00        85.0             NaN     NaN
# 9          Pass Completion %  70.1%        47.0             NaN     NaN
# 10        Progressive Passes   2.48        84.0             NaN     NaN
# 11       Progressive Carries   3.15        94.0             NaN     NaN
# 12       Successful Take-Ons   0.91        71.0             NaN     NaN
# 13         Touches (Att Pen)   7.62        97.0             NaN     NaN
# 14    Progressive Passes Rec   7.45        88.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   1.08        87.0             NaN     NaN
# 17             Interceptions   0.58        98.0             NaN     NaN
# 18                    Blocks   0.75        78.0             NaN     NaN
# 19                Clearances   0.41        20.0             NaN     NaN
# 20               Aerials Won   1.74        49.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  1087.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.00        17.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.05        55.0             NaN     NaN
# 2                Shots Total   0.82        66.0             NaN     NaN
# 3                    Assists   0.00         8.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.04        11.0             NaN     NaN
# 5                 npxG + xAG   0.09        22.0             NaN     NaN
# 6      Shot-Creating Actions   1.88        38.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  69.84        94.0             NaN     NaN
# 9          Pass Completion %  86.2%        88.0             NaN     NaN
# 10        Progressive Passes   5.98        93.0             NaN     NaN
# 11       Progressive Carries   1.76        44.0             NaN     NaN
# 12       Successful Take-Ons   0.29        14.0             NaN     NaN
# 13         Touches (Att Pen)   0.82        18.0             NaN     NaN
# 14    Progressive Passes Rec   1.93         4.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   1.70        33.0             NaN     NaN
# 17             Interceptions   1.05        62.0             NaN     NaN
# 18                    Blocks   1.41        76.0             NaN     NaN
# 19                Clearances   2.99        77.0             NaN     NaN
# 20               Aerials Won   1.70        95.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  1536.0,                    Statistic Per 90  Percentile            Stat  Value
# 0          Non-Penalty Goals   0.00        17.0             NaN    NaN
# 1       npxG: Non-Penalty xG   0.04        47.0             NaN    NaN
# 2                Shots Total   0.81        64.0             NaN    NaN
# 3                    Assists   0.20        89.0             NaN    NaN
# 4   xAG: Exp. Assisted Goals   0.21        94.0             NaN    NaN
# 5                 npxG + xAG   0.24        87.0             NaN    NaN
# 6      Shot-Creating Actions   3.23        91.0             NaN    NaN
# 7                        NaN    NaN         NaN             NaN    NaN
# 8           Passes Attempted  76.57        96.0             NaN    NaN
# 9          Pass Completion %  85.5%        87.0             NaN    NaN
# 10        Progressive Passes   6.97        97.0             NaN    NaN
# 11       Progressive Carries   1.92        52.0             NaN    NaN
# 12       Successful Take-Ons   0.51        35.0             NaN    NaN
# 13         Touches (Att Pen)   1.62        57.0             NaN    NaN
# 14    Progressive Passes Rec   4.24        50.0             NaN    NaN
# 15                       NaN    NaN         NaN             NaN    NaN
# 16                   Tackles   2.22        67.0             NaN    NaN
# 17             Interceptions   1.62        93.0             NaN    NaN
# 18                    Blocks   1.21        59.0             NaN    NaN
# 19                Clearances   2.32        41.0             NaN    NaN
# 20               Aerials Won   0.40        11.0             NaN    NaN
# 21                       NaN    NaN         NaN  Minutes Played  891.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.12        91.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.08        90.0             NaN     NaN
# 2                Shots Total   0.48        48.0             NaN     NaN
# 3                    Assists   0.00        27.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.01        18.0             NaN     NaN
# 5                 npxG + xAG   0.08        66.0             NaN     NaN
# 6      Shot-Creating Actions   0.96        66.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  83.61        95.0             NaN     NaN
# 9          Pass Completion %  89.7%        77.0             NaN     NaN
# 10        Progressive Passes   4.34        76.0             NaN     NaN
# 11       Progressive Carries   0.96        84.0             NaN     NaN
# 12       Successful Take-Ons   0.36        85.0             NaN     NaN
# 13         Touches (Att Pen)   0.96        63.0             NaN     NaN
# 14    Progressive Passes Rec   0.24        51.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   2.11        87.0             NaN     NaN
# 17             Interceptions   1.15        58.0             NaN     NaN
# 18                    Blocks   1.21        44.0             NaN     NaN
# 19                Clearances   3.38        25.0             NaN     NaN
# 20               Aerials Won   2.53        74.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  1493.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.00        17.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.10        89.0             NaN     NaN
# 2                Shots Total   1.20        90.0             NaN     NaN
# 3                    Assists   0.07        43.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.08        39.0             NaN     NaN
# 5                 npxG + xAG   0.18        67.0             NaN     NaN
# 6      Shot-Creating Actions   2.46        73.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  65.85        91.0             NaN     NaN
# 9          Pass Completion %  83.3%        76.0             NaN     NaN
# 10        Progressive Passes   3.66        50.0             NaN     NaN
# 11       Progressive Carries   3.80        94.0             NaN     NaN
# 12       Successful Take-Ons   1.06        79.0             NaN     NaN
# 13         Touches (Att Pen)   4.37        99.0             NaN     NaN
# 14    Progressive Passes Rec   5.99        85.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   3.03        95.0             NaN     NaN
# 17             Interceptions   1.06        62.0             NaN     NaN
# 18                    Blocks   1.55        86.0             NaN     NaN
# 19                Clearances   2.18        35.0             NaN     NaN
# 20               Aerials Won   1.27        81.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  1278.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.00        13.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.02         8.0             NaN     NaN
# 2                Shots Total   0.38         7.0             NaN     NaN
# 3                    Assists   0.00         8.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.11        69.0             NaN     NaN
# 5                 npxG + xAG   0.13        40.0             NaN     NaN
# 6      Shot-Creating Actions   2.63        61.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  70.24        89.0             NaN     NaN
# 9          Pass Completion %  89.3%        86.0             NaN     NaN
# 10        Progressive Passes   5.21        59.0             NaN     NaN
# 11       Progressive Carries   0.56        13.0             NaN     NaN
# 12       Successful Take-Ons   0.69        57.0             NaN     NaN
# 13         Touches (Att Pen)   0.69        24.0             NaN     NaN
# 14    Progressive Passes Rec   1.13        23.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   2.82        82.0             NaN     NaN
# 17             Interceptions   1.07        61.0             NaN     NaN
# 18                    Blocks   1.38        68.0             NaN     NaN
# 19                Clearances   1.51        58.0             NaN     NaN
# 20               Aerials Won   1.32        76.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  1435.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.28        97.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.20        95.0             NaN     NaN
# 2                Shots Total   2.79        99.0             NaN     NaN
# 3                    Assists   0.70        99.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.31        99.0             NaN     NaN
# 5                 npxG + xAG   0.50        98.0             NaN     NaN
# 6      Shot-Creating Actions   5.51        99.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  68.88        88.0             NaN     NaN
# 9          Pass Completion %  83.5%        46.0             NaN     NaN
# 10        Progressive Passes   8.02        94.0             NaN     NaN
# 11       Progressive Carries   2.72        94.0             NaN     NaN
# 12       Successful Take-Ons   0.63        52.0             NaN     NaN
# 13         Touches (Att Pen)   4.88        98.0             NaN     NaN
# 14    Progressive Passes Rec   7.95        98.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   1.39        13.0             NaN     NaN
# 17             Interceptions   0.63        17.0             NaN     NaN
# 18                    Blocks   1.60        86.0             NaN     NaN
# 19                Clearances   0.42         2.0             NaN     NaN
# 20               Aerials Won   0.28         8.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  1291.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.23        16.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.18         3.0             NaN     NaN
# 2                Shots Total   3.29        80.0             NaN     NaN
# 3                    Assists   0.08        26.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.27        96.0             NaN     NaN
# 5                 npxG + xAG   0.46        45.0             NaN     NaN
# 6      Shot-Creating Actions   5.43        99.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  30.69        91.0             NaN     NaN
# 9          Pass Completion %  70.6%        49.0             NaN     NaN
# 10        Progressive Passes   3.06        88.0             NaN     NaN
# 11       Progressive Carries   4.13        95.0             NaN     NaN
# 12       Successful Take-Ons   1.53        90.0             NaN     NaN
# 13         Touches (Att Pen)   5.28        64.0             NaN     NaN
# 14    Progressive Passes Rec  10.94        97.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   1.15        89.0             NaN     NaN
# 17             Interceptions   0.08        19.0             NaN     NaN
# 18                    Blocks   0.84        84.0             NaN     NaN
# 19                Clearances   0.00         1.0             NaN     NaN
# 20               Aerials Won   0.00         1.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  1176.0,                    Statistic Per 90  Percentile            Stat   Value
# 0          Non-Penalty Goals   0.00        14.0             NaN     NaN
# 1       npxG: Non-Penalty xG   0.06        52.0             NaN     NaN
# 2                Shots Total   0.95        53.0             NaN     NaN
# 3                    Assists   0.08        56.0             NaN     NaN
# 4   xAG: Exp. Assisted Goals   0.12        80.0             NaN     NaN
# 5                 npxG + xAG   0.18        71.0             NaN     NaN
# 6      Shot-Creating Actions   2.45        51.0             NaN     NaN
# 7                        NaN    NaN         NaN             NaN     NaN
# 8           Passes Attempted  61.60        82.0             NaN     NaN
# 9          Pass Completion %  84.8%        59.0             NaN     NaN
# 10        Progressive Passes   4.73        44.0             NaN     NaN
# 11       Progressive Carries   1.03        47.0             NaN     NaN
# 12       Successful Take-Ons   0.63        59.0             NaN     NaN
# 13         Touches (Att Pen)   1.50        72.0             NaN     NaN
# 14    Progressive Passes Rec   1.89        56.0             NaN     NaN
# 15                       NaN    NaN         NaN             NaN     NaN
# 16                   Tackles   1.34        11.0             NaN     NaN
# 17             Interceptions   0.63        13.0             NaN     NaN
# 18                    Blocks   1.58        84.0             NaN     NaN
# 19                Clearances   1.89        85.0             NaN     NaN
# 20               Aerials Won   0.63        36.0             NaN     NaN
# 21                       NaN    NaN         NaN  Minutes Played  1141.0], 'keepers': [                         Statistic Per 90  Percentile            Stat   Value
# 0                          PSxG-GA  -0.10        26.0             NaN     NaN
# 1                    Goals Against   1.00        93.0             NaN     NaN
# 2                  Save Percentage  70.8%        51.0             NaN     NaN
# 3                         PSxG/SoT   0.27        26.0             NaN     NaN
# 4           Clean Sheet Percentage  37.0%        85.0             NaN     NaN
# 5                              NaN    NaN         NaN             NaN     NaN
# 6                          Touches  38.50        61.0             NaN     NaN
# 7                         Launch %  18.1%        11.0             NaN     NaN
# 8                       Goal Kicks   2.58         1.0             NaN     NaN
# 9        Avg. Length of Goal Kicks   28.8         3.0             NaN     NaN
# 10                             NaN    NaN         NaN             NaN     NaN
# 11               Crosses Stopped %   3.7%        13.0             NaN     NaN
# 12  Def. Actions Outside Pen. Area   1.54        83.0             NaN     NaN
# 13   Avg. Distance of Def. Actions   16.2        89.0             NaN     NaN
# 14                             NaN    NaN         NaN  Minutes Played  2508.0,                          Statistic  Per 90  Percentile            Stat   Value
# 0                          PSxG-GA   +0.31        98.0             NaN     NaN
# 1                    Goals Against    1.09        86.0             NaN     NaN
# 2                  Save Percentage   73.7%        74.0             NaN     NaN
# 3                         PSxG/SoT    0.31        76.0             NaN     NaN
# 4            Save% (Penalty Kicks)  100.0%        97.0             NaN     NaN
# 5           Clean Sheet Percentage   30.4%        70.0             NaN     NaN
# 6                              NaN     NaN         NaN             NaN     NaN
# 7                          Touches   44.17        93.0             NaN     NaN
# 8                         Launch %   26.2%        27.0             NaN     NaN
# 9                       Goal Kicks    2.70         2.0             NaN     NaN
# 10       Avg. Length of Goal Kicks    36.2        19.0             NaN     NaN
# 11                             NaN     NaN         NaN             NaN     NaN
# 12               Crosses Stopped %    5.8%        45.0             NaN     NaN
# 13  Def. Actions Outside Pen. Area    1.30        75.0             NaN     NaN
# 14   Avg. Distance of Def. Actions    16.5        91.0             NaN     NaN
# 15                             NaN     NaN         NaN  Minutes Played  2070.0]}
#
# ===== Liverpool Stats - PLAYERS =====
#                     Statistic Per 90  Percentile            Stat   Value
# 0           Non-Penalty Goals   0.06        72.0             NaN     NaN
# 1        npxG: Non-Penalty xG   0.07        85.0             NaN     NaN
# 2                 Shots Total   0.96        96.0             NaN     NaN
# 3                     Assists   0.02        53.0             NaN     NaN
# 4    xAG: Exp. Assisted Goals   0.02        52.0             NaN     NaN
# ..                        ...    ...         ...             ...     ...
# 457             Interceptions   0.63        13.0             NaN     NaN
# 458                    Blocks   1.58        84.0             NaN     NaN
# 459                Clearances   1.89        85.0             NaN     NaN
# 460               Aerials Won   0.63        36.0             NaN     NaN
# 461                       NaN    NaN         NaN  Minutes Played  1141.0
#
# [462 rows x 5 columns]
# Saved Liverpool Stats_players.csv
#
# ===== Liverpool Stats - KEEPERS =====
#                          Statistic  Per 90  Percentile            Stat   Value
# 0                          PSxG-GA   -0.10        26.0             NaN     NaN
# 1                    Goals Against    1.00        93.0             NaN     NaN
# 2                  Save Percentage   70.8%        51.0             NaN     NaN
# 3                         PSxG/SoT    0.27        26.0             NaN     NaN
# 4           Clean Sheet Percentage   37.0%        85.0             NaN     NaN
# 5                              NaN     NaN         NaN             NaN     NaN
# 6                          Touches   38.50        61.0             NaN     NaN
# 7                         Launch %   18.1%        11.0             NaN     NaN
# 8                       Goal Kicks    2.58         1.0             NaN     NaN
# 9        Avg. Length of Goal Kicks    28.8         3.0             NaN     NaN
# 10                             NaN     NaN         NaN             NaN     NaN
# 11               Crosses Stopped %    3.7%        13.0             NaN     NaN
# 12  Def. Actions Outside Pen. Area    1.54        83.0             NaN     NaN
# 13   Avg. Distance of Def. Actions    16.2        89.0             NaN     NaN
# 14                             NaN     NaN         NaN  Minutes Played  2508.0
# 15                         PSxG-GA   +0.31        98.0             NaN     NaN
# 16                   Goals Against    1.09        86.0             NaN     NaN
# 17                 Save Percentage   73.7%        74.0             NaN     NaN
# 18                        PSxG/SoT    0.31        76.0             NaN     NaN
# 19           Save% (Penalty Kicks)  100.0%        97.0             NaN     NaN
# 20          Clean Sheet Percentage   30.4%        70.0             NaN     NaN
# 21                             NaN     NaN         NaN             NaN     NaN
# 22                         Touches   44.17        93.0             NaN     NaN
# 23                        Launch %   26.2%        27.0             NaN     NaN
# 24                      Goal Kicks    2.70         2.0             NaN     NaN
# 25       Avg. Length of Goal Kicks    36.2        19.0             NaN     NaN
# 26                             NaN     NaN         NaN             NaN     NaN
# 27               Crosses Stopped %    5.8%        45.0             NaN     NaN
# 28  Def. Actions Outside Pen. Area    1.30        75.0             NaN     NaN
# 29   Avg. Distance of Def. Actions    16.5        91.0             NaN     NaN
# 30                             NaN     NaN         NaN  Minutes Played  2070.0
# Saved Liverpool Stats_keepers.csv
